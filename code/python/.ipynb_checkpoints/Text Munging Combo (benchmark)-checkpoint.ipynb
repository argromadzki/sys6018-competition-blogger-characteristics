# %%
import os
import numpy as np
import pandas as pd
import sklearn as slr
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

# %%
# Set wd
os.chdir("C://Users/alxgr//Documents//UVA//DSI//Fall 2018//SYS//Kaggle Competition 3//sys6018-competition-blogger-characteristics//data")
# os.chdir("/Users/SM/DSI/classes/fall2018/SYS6018/kaggle/sys6018-competition-blogger-characteristics/")

# %%
# read in data
# train = pd.read_csv(os.path.join("data", "input", "train.csv"))
# test = pd.read_csv(os.path.join("data", "input", "test.csv"))

# (os.path did not work for alex.  below for wd on alex's pc)
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
# convert to datetime, leaving non-valid/non-English dates null
train['date_date'] = pd.to_datetime(train.date, errors='coerce')
test['date_date'] = pd.to_datetime(test.date, errors='coerce')

# %%
# Remove rows where date cannot be parsed - these are non-English and so unless translated
# into English, cannot be used in a text model with this corpus
train = train[train['date_date'].notnull()]
train.date = train.date_date
train = train.drop(['date_date'], axis=1)

# %%
# Exploratory analysis

idfreq = train.groupby(['user.id']).agg({'post.id':[len], 'age':[max]})
idfreq.columns = idfreq.columns.droplevel(1)
idfreq

idfreq.columns= ["Post Freq", "Age"]

sns.regplot(x='Post Freq', y='Age', data=idfreq, scatter_kws={'alpha':0.2})
plt.xlim(0, 50)
# Out:
# (0, 50)

# %%
sns.regplot(x='Post Freq', y='Age', data=idfreq, scatter_kws={'alpha':0.2})
plt.xlim(0, 500)
# Out:
# (0, 500)

# %%
sns.regplot(x='Post Freq', y='Age', data=idfreq, scatter_kws={'alpha':0.2})

# %%
age_per_topic = train.groupby(['topic']).agg({"age" : [np.mean]})
age_per_topic
# Out:
#                                age
#                               mean
# topic
# Accounting               26.083295
# Advertising              29.439648
# Agriculture              23.636136
# Architecture             25.749260
# Arts                     24.717653
# Automotive               28.759259
# Banking                  26.036380
# Biotech                  23.045685
# BusinessServices         28.512966
# Chemicals                23.151493
# Communications-Media     26.438036
# Construction             27.838658
# Consulting               28.462083
# Education                25.916899
# Engineering              25.039390
# Environment              22.144186
# Fashion                  27.920727
# Government               28.535961
# HumanResources           26.876852
# Internet                 28.335452
# InvestmentBanking        28.057912
# Law                      27.237913
# LawEnforcement-Security  21.457576
# Manufacturing            27.762032
# Maritime                 22.906832
# Marketing                26.640064
# Military                 26.686908
# Museums-Libraries        29.936514
# Non-Profit               24.503877
# Publishing               29.604560
# RealEstate               22.129785
# Religion                 28.353556
# Science                  25.069815
# Sports-Recreation        22.321839
# Student                  17.906781
# Technology               26.303598
# Telecommunications       28.425661
# Tourism                  25.791732
# Transportation           32.500000
# indUnk                   24.005672

# %%
# nltk.download('stopwords')
# nltk.download('punkt')

# %%
porter = nltk.stem.porter.PorterStemmer()
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
train['text'] = train['text'].apply(str.lower) # lowercase, tokenize & stem words in text
train['tokens']=train['text'].apply(nltk.word_tokenize) # separate by words/punctuation/etc.
train['tokens']=[[porter.stem(x) for x in tokens] for tokens in train['tokens']] # stem words
train['tokens']=[[w for w in tokens if not w in stop_words] for tokens in train['tokens']] # stop words
train['tokens']=[[w for w in tokens if w.isalpha()] for tokens in train['tokens']]

# %% [markdown]
# first tokens line: for each cell in text column, produces a list of tokens
#
# second line: for each list in series of lists (the column), look at a single token, run the stemmer on each token
#
# third line: for each of the cells, look at each list of tokens (now stemmed), check if each individual token (a word) is a stopword
#
# fourth line: for each of the cells, look at the list of tokens (stemmed, not stop words), filter out anything that is not strictly alphabetic characters (excludes punctuation and numeric that might have been confused by the stemmer)

# %%
train['newtext'] = train['tokens'].apply(lambda x: " ".join(x)) # concatenate tokens within a cell

# %%
# save each document with reduced text to csv
train.to_csv("Corpus.csv")

# %%
# Create Term-Document Matrix (edited below for dimension reduction)
# vectorizer = slr.feature_extraction.text.CountVectorizer()
# tdm = vectorizer.fit_transform(train['newtext'])

# %%
# Reduce TDM Dimensionality
vectorizer = slr.feature_extraction.text.CountVectorizer(min_df=.0005)
tdm_reduced = vectorizer.fit_transform(train['newtext'])
tdm_reduced
# Out:
# <438492x9270 sparse matrix of type '<class 'numpy.int64'>'
# 	with 29732058 stored elements in Compressed Sparse Row format>

# %%
# Saving vectorizer headings
feature_headings = vectorizer.get_feature_names()

# %%
# TFIDF transform
transformer = slr.feature_extraction.text.TfidfTransformer(smooth_idf=False)
tfidf = transformer.fit_transform(tdm_reduced)

# %%
sp.sparse.save_npz("Training_TF_IDF_01.npz", tfidf)

# %%
# tfidf.to_csv("Training_TF_IDF_01.csv")
# tfidf.todense() # it is too big of a file to do this
# type(tfidf)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
# tfidf = sp.sparse.load_npz("Training_TF_IDF_01.npz")
# np_array_tfidf = np.load("Training_TF_IDF_01.npz")

# %%
# array_tfidf= np.asarray(tfidf)
# np_array_tfidf['data'] # this did not work
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-87-8a7fff7bf352> in <module>()
#       1 array_tfidf= np.asarray(tfidf)
# ----> 2 np_array_tfidf['data'] # this did not work
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in __getitem__(self, key)
#     233                 return format.read_array(bytes,
#     234                                          allow_pickle=self.allow_pickle,
# --> 235                                          pickle_kwargs=self.pickle_kwargs)
#     236             else:
#     237                 return self.zip.read(key)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     681                     read_count = min(max_read_count, count - i)
#     682                     read_size = int(read_count * dtype.itemsize)
# --> 683                     data = _read_bytes(fp, read_size, "array data")
#     684                     array[i:i+read_count] = numpy.frombuffer(data, dtype=dtype,
#     685                                                              count=read_count)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\format.py in _read_bytes(fp, size, error_template)
#     820         # done about that.  note that regular files can't be non-blocking
#     821         try:
# --> 822             r = fp.read(size - len(data))
#     823             data += r
#     824             if len(r) == 0 or len(data) == size:
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in read(self, n)
#     847         self._offset = 0
#     848         while n > 0 and not self._eof:
# --> 849             data = self._read1(n)
#     850             if n < len(data):
#     851                 self._readbuffer = data
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in _read1(self, n)
#     937         if self._left <= 0:
#     938             self._eof = True
# --> 939         self._update_crc(data)
#     940         return data
#     941
#
# C:\ProgramData\Anaconda3\lib\zipfile.py in _update_crc(self, newdata)
#     865         # Check the CRC if we're at the end of the file
#     866         if self._eof and self._running_crc != self._expected_crc:
# --> 867             raise BadZipFile("Bad CRC-32 for file %r" % self.name)
#     868
#     869     def read1(self, n):
#
# BadZipFile: Bad CRC-32 for file 'data.npy'

# %%
porter = nltk.stem.porter.PorterStemmer()
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
test['text'] = test['text'].apply(str.lower) # lowercase, tokenize & stem words in text
test['tokens']=test['text'].apply(nltk.word_tokenize) # separate by words/punctuation/etc.
test['tokens']=[[porter.stem(x) for x in tokens] for tokens in test['tokens']] # stem words
test['tokens']=[[w for w in tokens if not w in stop_words] for tokens in test['tokens']] # stop words
test['tokens']=[[w for w in tokens if w.isalpha()] for tokens in test['tokens']]

# %%
test['newtext'] = test['tokens'].apply(lambda x: " ".join(x)) # concatenate tokens within a cell

# %%
test.to_csv("Testing_Corpus.csv")

# %%
# Reduce Test-TDM Dimensionality
vectorizer = slr.feature_extraction.text.CountVectorizer(min_df=.0005)
test_tdm_reduced = vectorizer.fit_transform(test['newtext'])
test_tdm_reduced
# Out:
# <238323x8994 sparse matrix of type '<class 'numpy.int64'>'
# 	with 15365269 stored elements in Compressed Sparse Row format>

# %%
feature_headings = vectorizer.get_feature_names()

# %%
transformer = slr.feature_extraction.text.TfidfTransformer(smooth_idf=False)
test_tfidf = transformer.fit_transform(test_tdm_reduced)

# %%
sp.sparse.save_npz("Testing_TF_IDF_01.npz", test_tfidf)

# %%
test.head()
# Out:
#    post.id  user.id  gender    topic       sign            date  \
# 0       96     4876  female   indUnk  Capricorn  08,August,2004
# 1       97     4876  female   indUnk  Capricorn  08,August,2004
# 2      108    12227  female  Student      Aries    31,July,2004
# 3      109    12227  female  Student      Aries    30,July,2004
# 4      110    12227  female  Student      Aries    29,July,2004
#
#                                                 text  date_date  \
# 0                    urllink     im new to this, ... 2004-08-08
# 1                    election time has rolled aro... 2004-08-08
# 2                   met lim this morning, then we... 2004-07-31
# 3                   such a boring day. i have no ... 2004-07-30
# 4                   nuts. as usual, theo and i pl... 2004-07-29
#
#                                               tokens  \
# 0  [urllink, im, new, thi, tell, god, creat, link...
# 1  [elect, time, ha, roll, around, everyon, spit,...
# 2  [met, lim, thi, morn, went, spc, get, help, ch...
# 3  [bore, day, comment, found, shortest, girl, cl...
# 4  [nut, usual, theo, play, food, today, creation...
#
#                                              newtext
# 0      urllink im new thi tell god creat link column
# 1  elect time ha roll around everyon spit venom h...
# 2  met lim thi morn went spc get help choic math ...
# 3  bore day comment found shortest girl class ver...
# 4  nut usual theo play food today creation consis...

# %%
pd.read_csv('Testing_Corpus.csv')
